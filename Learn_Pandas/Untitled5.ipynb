# %%
import pandas as pd

# %%
import mysql.connector as sconn
con=sconn.connect(host='localhost',user='root',password='lava')
print(con)

# %%
# pip install --upgrade pandas jupyter notebook ipykernel
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/14.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/14.3 MB 2.5 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/14.3 MB 2.5 MB/s eta 0:00:06
#    -- ------------------------------------- 1.0/14.3 MB 1.2 MB/s eta 0:00:11
#    ------ --------------------------------- 2.4/14.3 MB 2.3 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.9/14.3 MB 3.2 MB/s eta 0:00:04
#    ------------- -------------------------- 5.0/14.3 MB 3.5 MB/s eta 0:00:03
#    ------------------ --------------------- 6.6/14.3 MB 3.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.9/14.3 MB 4.2 MB/s eta 0:00:02
#    ------------------------ --------------- 8.9/14.3 MB 4.2 MB/s eta 0:00:02
#    -------------------------- ------------- 9.4/14.3 MB 4.0 MB/s eta 0:00:02
# ...

# %%
import mysl.connector
