# %% [markdown]
# #

# %%
import pandas as pd

# %% [markdown]
# # value_counts()--
# ### it returns frequency count of each entery

# %%
pd.DataFrame([[10,20,30,40],
              ['lava','a','b','c'],
              [89,34,56,78]],columns=['id','name','percentage','marks'])
# Out:
#      id name percentage marks
# 0    10   20         30    40
# 1  lava    a          b     c
# 2    89   34         56    78

# %%
df=pd.read_csv('Documents/Learn_Pandas/ipl-matches.csv')
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
# Toss Decision Plot

# %%
df['TossDecision'].value_counts()
df['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# how many matches are each team played
df['Team1'].value_counts()+df['Team2'].value_counts()
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %% [markdown]
# # sort_values()---
# #### (serise and dataframe)->na_position -> ascending-> inplace

# %%
s=pd.Series([1,1,1,2,3,4,4])
s.sort_values()
s.sort_values(ascending=False)
# Out:
# 6    4
# 5    4
# 4    3
# 3    2
# 2    1
# 0    1
# 1    1
# dtype: int64

# %%
df.sort_values('Team1')
# Out:
#           ID       City        Date   Season MatchNumber                Team1  \
# 676   548332    Chennai  2012-04-21     2012          26  Chennai Super Kings
# 531   733971     Ranchi  2014-05-02     2014          21  Chennai Super Kings
# 893   336039     Mumbai  2008-05-31  2007/08  Semi Final  Chennai Super Kings
# 733   501240    Chennai  2011-05-04     2011          43  Chennai Super Kings
# 892   336040     Mumbai  2008-06-01  2007/08       Final  Chennai Super Kings
# ..       ...        ...         ...      ...         ...                  ...
# 372  1082591  Hyderabad  2017-04-05     2017           1  Sunrisers Hyderabad
# 513   734007  Hyderabad  2014-05-14     2014          39  Sunrisers Hyderabad
# 510   734015  Hyderabad  2014-05-18     2014          43  Sunrisers Hyderabad
# 421   980923  Hyderabad  2016-04-18     2016          12  Sunrisers Hyderabad
# 213  1178416    Chennai  2019-04-23     2019          41  Sunrisers Hyderabad
#
# ...

# %%
#na_position
df.sort_values('City',na_position='first')
# Out:
#           ID           City        Date   Season  MatchNumber  \
# 134  1237181            NaN  2020-11-10  2020/21        Final
# 137  1237177            NaN  2020-11-05  2020/21  Qualifier 1
# 138  1216495            NaN  2020-11-03  2020/21           56
# 140  1216530            NaN  2020-11-01  2020/21           54
# 142  1216535            NaN  2020-10-31  2020/21           51
# ..       ...            ...         ...      ...          ...
# 196  1181766  Visakhapatnam  2019-05-08     2019   Eliminator
# 195  1181767  Visakhapatnam  2019-05-10     2019    Qualifier
# 472   829743  Visakhapatnam  2015-04-22     2015           19
# 380   981005  Visakhapatnam  2016-05-21     2016           53
# 384   980997  Visakhapatnam  2016-05-17     2016           49
#
#                        Team1                  Team2  \
# 134           Delhi Capitals         Mumbai Indians
# 137           Mumbai Indians         Delhi Capitals
# 138           Mumbai Indians    Sunrisers Hyderabad
# ...

# %%
df.head(2)
df.sort_values(['Season','Team1'],ascending=[True,False])
# Out:
#           ID       City        Date   Season MatchNumber  \
# 896   336012  Bangalore  2008-05-28  2007/08          55
# 907   336026  Bangalore  2008-05-19  2007/08          43
# 925   336006  Bangalore  2008-05-05  2007/08          25
# 928   336034  Bangalore  2008-05-03  2007/08          21
# 935   335996  Bangalore  2008-04-28  2007/08          15
# ..       ...        ...         ...      ...         ...
# 45   1304075       Pune  2022-04-17     2022          29
# 52   1304068     Mumbai  2022-04-12     2022          22
# 57   1304063     Mumbai  2022-04-09     2022          17
# 67   1304053     Mumbai  2022-03-31     2022           7
# 73   1304047     Mumbai  2022-03-26     2022           1
#
#                            Team1                        Team2  \
# 896  Royal Challengers Bangalore               Mumbai Indians
# 907  Royal Challengers Bangalore             Delhi Daredevils
# 925  Royal Challengers Bangalore              Kings XI Punjab
# ...

# %%
import pandas as pd
apptemp=pd.DataFrame([['lava','madure',10],
              ['ngesj','miranam',20],
             ['lavanya','miranam',80]],columns=['first','last','percentage'])
apptemp
# Out:
#      first     last  percentage
# 0     lava   madure          10
# 1    ngesj  miranam          20
# 2  lavanya  miranam          80

# %%
def transform(row):
    return str(row['first'])+str(row['last'])
    
apptemp.apply(transform,axis=1)
# Out:
# 0        lavamadure
# 1      ngesjmiranam
# 2    lavanyamiranam
# dtype: object
